# %%
import pandas as pd
from read_files import *
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
from gensim.models import CoherenceModel

np.random.seed(2018)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-14ff7dd154ae> in <module>()
#       1 import pandas as pd
# ----> 2 from read_files import *
#       3 import gensim
#       4 from gensim.utils import simple_preprocess
#       5 from gensim.parsing.preprocessing import STOPWORDS
#
# ModuleNotFoundError: No module named 'read_files'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#!python -m spacy download es_core_news_md
#import nltk
#nltk.download("stopwords")

# %%
df = pd.read_csv("data_training.csv")

# %%
df = get_data("data/CIAT")

# %%
df
# Out:
#                                              document  \
# 0   CONVENIO BASIC0 DE COOPERACION TECNICA Y CIENT...
# 1   entro Australiano para la Investigación Agríco...
# 2
# 3   Acerca de la investigación sobre agrobiodivers...
# 4   El Laboratorio de Servicios Analíticos del CIA...
# 5   El Centro Internacional de Agricultura Tropica...
# 6   \n\n\nObservatorio Colombiano de Ciencia y Tec...
# 7   Polania, J., Rao, I.M., Cajiao,  Raatz, B., Be...
# 8   La segunda reunión de la Red Colombiana de For...
# 9   Cuando se trata de tecnologías digitales e inn...
# 10  Validar los procesos de investigación iniciado...
#
#                           topic                          file  \
# 0      Convenios de Cooperacion  Convenios de cooperaciòn.txt
# 1                   Cooperantes               cooperantes.txt
# 2                 Investigacion                      inv1.txt
# 3                 Investigacion             Investigaciòn.txt
# ...

# %%
dictionary = gensim.corpora.Dictionary(df['clean_text'])

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 academia
# 1 académico
# 2 aceptar
# 3 actividad
# 4 actor
# 5 actual
# 6 actualizado
# 7 actualmente
# 8 acuerdo
# 9 adaptación
# 10 adaptado

# %%
dictionary.filter_extremes(no_below=2, keep_n=10)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in df['clean_text']]

# %%
corpus = [dictionary.doc2bow(text) for text in df['clean_text']]

# %%
corpus
# Out:
# [[(0, 2),
#   (1, 4),
#   (2, 1),
#   (3, 1),
#   (4, 3),
#   (5, 1),
#   (6, 1),
#   (7, 1),
#   (8, 3),
#   (9, 1),
#   (10, 1),
#   (11, 1),
#   (12, 1),
#   (13, 9),
#   (14, 1),
#   (15, 2),
#   (16, 1),
#   (17, 1),
#   (18, 9),
#   (19, 2),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 1),
#   (26, 2),
#   (27, 1),
#   (28, 2),
#   (29, 13),
#   (30, 1),
#   (31, 1),
#   (32, 4),
#   (33, 1),
#   (34, 3),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 3),
#   (41, 1),
#   (42, 10),
#   (43, 1),
#   (44, 1),
#   (45, 1),
#   (46, 1),
#   (47, 2),
#   (48, 1),
#   (49, 19),
#   (50, 1),
#   (51, 2),
#   (52, 1),
#   (53, 4),
#   (54, 6),
#   (55, 4),
#   (56, 1),
#   (57, 1),
#   (58, 1),
#   (59, 2),
#   (60, 2),
#   (61, 3),
#   (62, 1),
#   (63, 1),
#   (64, 1),
#   (65, 7),
#   (66, 1),
#   (67, 6),
#   (68, 1),
#   (69, 3),
#   (70, 1),
#   (71, 1),
#   (72, 1),
#   (73, 2),
#   (74, 1),
#   (75, 1),
#   (76, 1),
# ...

# %%
dictionary[0]
# Out:
# 'academia'

# %%
[[(dictionary[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('academia', 2),
#   ('académico', 4),
#   ('aceptar', 1),
#   ('actividad', 1),
#   ('actor', 3),
#   ('actual', 1),
#   ('actualizado', 1),
#   ('actualmente', 1),
#   ('acuerdo', 3),
#   ('adaptación', 1),
#   ('adaptado', 1),
#   ('aesfrut', 1),
#   ('agregado', 1),
#   ('agricultura', 9),
#   ('agro', 1),
#   ('agroindustria', 2),
#   ('agroindustrial', 1),
#   ('agropecuario', 1),
#   ('agrícola', 9),
#   ('aliado', 2),
#   ('alianza', 1),
#   ('alimentar', 1),
#   ('alimentario', 1),
#   ('alimento', 1),
#   ('altamente', 1),
#   ('alto', 1),
#   ('ambiental', 2),
#   ('ampliado', 1),
#   ('analizar', 2),
#   ('análisis', 13),
#   ('apartir', 1),
#   ('aplazado', 1),
#   ('aplicar', 4),
#   ('aportar', 1),
#   ('aporte', 3),
#   ('apoyo', 1),
#   ('aprobación', 1),
#   ('aprobado', 1),
#   ('apropiación', 1),
#   ('aprovechamiento', 1),
#   ('aprovechar', 3),
#   ('arco', 1),
#   ('artículo', 10),
#   ('asignación', 1),
#   ('asociado', 1),
#   ('asociativamente', 1),
# ...

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=2, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 10 topics
print(lda_model.print_topics())

doc_lda = lda_model[corpus]
# Out:
# [(0, '0.016*"investigación" + 0.011*"desarrollo" + 0.009*"red" + 0.009*"universidad" + 0.008*"organización" + 0.008*"autor" + 0.008*"análisis" + 0.007*"colombia" + 0.006*"agrícola" + 0.006*"dentro"'), (1, '0.014*"innovación" + 0.011*"desarrollo" + 0.011*"investigación" + 0.010*"tecnología" + 0.009*"tecnológico" + 0.009*"nacional" + 0.009*"ciencia" + 0.008*"científico" + 0.007*"programa" + 0.007*"política"')]

# %%
import os

os.listdir('data/CIAT')
path = 'data/CIAT'

# %%
dir_list = [i for i in os.listdir(path)]
dir_list
# Out:
# ['Cientificos',
#  'Convenios de Cooperacion',
#  'Cooperantes',
#  'Investigacion',
#  'Laboratorios',
#  'Organizacional',
#  'Polìtica CTeI',
#  'Redes de actores',
#  'Tecnologìa',
#  'Transferencia de tecnologia']

# %%
x = []
for dir in dir_list:
    files_dir = [i for i in os.listdir(path+'/'+dir+'/')]
    for file in files_dir:
        with open(path+'/'+dir+'/'+file,"r") as f:
            texto = f.read()
            salida = [texto,dir,file]
            x.append(salida)

# %%
def clean_tokenize(texto):
    '''
    Esta función limpia y tokeniza el texto en palabras individuales.
    El orden en el que se va limpiando el texto no es arbitrario.
    El listado de signos de puntuación se ha obtenido de: print(string.punctuation)
    y re.escape(string.punctuation). La funcion tambien elimina stop words y realiza una
    lematizacion de palablas en español
    '''
    # lista de stop words en español
    stop_words = stopwords.words('spanish')
    # Cargando nlp para lematizar
    nlp = es_core_news_md.load()
    # Se convierte todo el texto a minúsculas
    nuevo_texto = texto.lower()
    # Eliminación de páginas web (palabras que empiezan por "http")
    nuevo_texto = re.sub('http\S+', ' ', nuevo_texto)
    # Eliminación de signos de puntuación
    regex = '[\\!\\"\\#\\$\\%\\&\\\'\\(\\)\\*\\+\\,\\-\\.\\/\\:\\;\\<\\=\\>\\?\\@\\[\\\\\\]\\^_\\`\\{\\|\\}\\~]'
    nuevo_texto = re.sub(regex , ' ', nuevo_texto)
    # Eliminación de números
    nuevo_texto = re.sub("\d+", ' ', nuevo_texto)
    # Eliminación de espacios en blanco múltiples
    nuevo_texto = re.sub("\\s+", ' ', nuevo_texto)
    # Tokenización por palabras individuales
    #nuevo_texto = nuevo_texto.split(sep = ' ')
    nuevo_texto = nlp(nuevo_texto)
    # Eliminación de tokens con una longitud < 2
    nuevo_texto = [token.lemma_ for token in nuevo_texto if len(token) > 1 if not str(token) in stop_words]
    
    return(nuevo_texto)

# %%
xx = pd.DataFrame(x,columns = ['document','topic','file'] )

# %%
xx['document'].apply(clean_tokenize)
# Out:
# 0     [convenio, basic, cooperacion, tecnico, cienti...
# 1     [entro, australiano, investigación, agrícola, ...
# 2                                                    []
# 3     [acerca, investigación, agrobiodiversidad, cia...
# 4     [laboratorio, servicio, analítico, ciat, cread...
# 5     [centro, internacional, agricultura, tropical,...
# 6     [observatorio, colombiano, ciencia, tecnología...
# 7     [polania, rao, cajiao, raatz, beebe, holguín, ...
# 8     [segundo, reunión, red, colombiano, forraj, ll...
# 9     [tratar, tecnología, digital, innovación, form...
# 10    [validar, proceso, investigación, iniciado, ni...
# Name: document, dtype: object

# %%
import re
regex = '[\\!\\"\\#\\$\\%\\&\\\'\\(\\)\\*\\+\\,\\-\\.\\/\\:\\;\\<\\=\\>\\?\\@\\[\\\\\\]\\^_\\`\\{\\|\\}\\~]'
nuevo_texto = re.sub(regex , ' ', x[0])

# %%
from read_files import clean_tokenize
import pandas as pd

# %%
pd.Series(x)
# Out:
# 0     CONVENIO BASIC0 DE COOPERACION TECNICA Y CIENT...
# 1     entro Australiano para la Investigación Agríco...
# 2
# 3     Acerca de la investigación sobre agrobiodivers...
# 4     El Laboratorio de Servicios Analíticos del CIA...
# 5     El Centro Internacional de Agricultura Tropica...
# 6     \n\n\nObservatorio Colombiano de Ciencia y Tec...
# 7     Polania, J., Rao, I.M., Cajiao,  Raatz, B., Be...
# 8     La segunda reunión de la Red Colombiana de For...
# 9     Cuando se trata de tecnologías digitales e inn...
# 10    Validar los procesos de investigación iniciado...
# dtype: object

# %%
t = x[0][0]
nuevo_texto = t.lower()
#nuevo_texto

# %%
nuevo_texto = re.sub('http\S+', ' ', nuevo_texto)

# %%
regex = '[\\!\\"\\#\\$\\%\\&\\\'\\(\\)\\*\\+\\,\\-\\.\\/\\:\\;\\<\\=\\>\\?\\@\\[\\\\\\]\\^_\\`\\{\\|\\}\\~]'
nuevo_texto = re.sub(regex , ' ', nuevo_texto)
nuevo_texto = re.sub("\d+", ' ', nuevo_texto)
nuevo_texto = re.sub("\\s+", ' ', nuevo_texto)

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/wilmar3752/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nuevo_texto
# Out:
# 'convenio basic de cooperacion tecnica y cientifica en el area agropecuaria forestal y de fauna entre el gobierno de la republica del peru y el centro internacional de agricultura tropical ciat el gobierno de la republica del per y el centro internacional de agricultura tropical ciat deseosos de estrechar s vinculos existentes de cooperacibn tkcnica y cientifica entre el peru y el ciat han resuelto celebrar para realizar estos propbsitos un convenio basico de cooperacibn tccnica y cientifica en s tkrminos siguientes articulo i ayuda y cooperacion internacional el gobierno de la republica del peru y el centro internacional de agricultura tropical ciat cooperarin y sc ayudarin dcntro de sus posibilidades para propender al desarrollo tkcnico y cientifico de la investigacibn agraria orientindola a la produccibn de productos alimenticios bisicos el establecimiento de sistemas de investigacibn agropecuaria forestal y de fauna el intercambio y formacibn de expertos y cientificos el intercam
# ...

# %%
word_tokens  = word_tokenize(nuevo_texto)

# %%
from nltk.corpus import stopwords

# %%
stop_words = set(stopwords.words('spanish'))

# %%
filtered_sentence = [w for w in word_tokens if not w in stop_words]

# %%
from nltk.corpus import swadesh
nltk.download('swadesh')
# Out:
# [nltk_data] Downloading package swadesh to
# [nltk_data]     /home/wilmar3752/nltk_data...
# [nltk_data]   Unzipping corpora/swadesh.zip.
# True

# %%
print(swadesh.fileids())
# Out:
# ['be', 'bg', 'bs', 'ca', 'cs', 'cu', 'de', 'en', 'es', 'fr', 'hr', 'it', 'la', 'mk', 'nl', 'pl', 'pt', 'ro', 'ru', 'sk', 'sl', 'sr', 'sw', 'uk']

# %%
est2eng = swadesh.entries(['es','en'])

# %%
print(est2eng)
# Out:
# [('yo', 'I'), ('tú, usted', 'you (singular), thou'), ('él', 'he'), ('nosotros', 'we'), ('vosotros, ustedes', 'you (plural)'), ('ellos, ellas', 'they'), ('este', 'this'), ('ese, aquel', 'that'), ('aquí, acá', 'here'), ('ahí, allí, allá', 'there'), ('quien', 'who'), ('que', 'what'), ('donde', 'where'), ('cuando', 'when'), ('como', 'how'), ('no', 'not'), ('todo', 'all'), ('muchos', 'many'), ('algunos, unos', 'some'), ('poco', 'few'), ('otro', 'other'), ('uno', 'one'), ('dos', 'two'), ('tres', 'three'), ('cuatro', 'four'), ('cinco', 'five'), ('grande', 'big'), ('largo', 'long'), ('ancho', 'wide'), ('gordo', 'thick'), ('pesado', 'heavy'), ('pequeño', 'small'), ('corto', 'short'), ('estrecho, angosto', 'narrow'), ('delgado, flaco', 'thin'), ('mujer', 'woman'), ('hombre', 'man (adult male)'), ('hombre', 'man (human being)'), ('niño', 'child'), ('esposa, mujer', 'wife'), ('esposo, marido', 'husband'), ('madre', 'mother'), ('padre', 'father'), ('animal', 'animal'), ('pez, pescado', 'fish'), (
# ...

# %%
translate = dict(est2eng)

# %%
translate["hola"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /mnt/c/Users/JUNIOR/Google Drive/proyectos_treedata/ensayos.ipynb Cell 42' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/JUNIOR/Google%20Drive/proyectos_treedata/ensayos.ipynb#ch0000042vscode-remote?line=0'>1</a> translate["hola"]
#
# KeyError: 'hola'

# %%
from deep_translator import GoogleTranslator

# %%
traductor = GoogleTranslator(source='es', target='en')
resultado = traductor.translate("La educación es el arma más poderosa para cambiar al mundo")
print(resultado)
# Out:
# Education is the most powerful weapon to change the world

# %%
traductor.translate(nuevo_texto)
# Out:
# ---------------------------------------------------------------------------
# NotValidLength                            Traceback (most recent call last)
# /mnt/c/Users/JUNIOR/Google Drive/proyectos_treedata/ensayos.ipynb Cell 45' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/mnt/c/Users/JUNIOR/Google%20Drive/proyectos_treedata/ensayos.ipynb#ch0000058vscode-remote?line=0'>1</a> traductor.translate(nuevo_texto)
#
# File ~/anaconda3/envs/nlp/lib/python3.10/site-packages/deep_translator/google.py:55, in GoogleTranslator.translate(self, text, **kwargs)
#      <a href='file:///home/wilmar3752/anaconda3/envs/nlp/lib/python3.10/site-packages/deep_translator/google.py?line=48'>49</a> def translate(self, text: str, **kwargs) -> str:
#      <a href='file:///home/wilmar3752/anaconda3/envs/nlp/lib/python3.10/site-packages/deep_translator/google.py?line=49'>50</a>     """
# ...
